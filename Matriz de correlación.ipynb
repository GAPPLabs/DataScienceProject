# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
dataframe = pd.read_csv("futbol.csv", parse_dates= True)

# %%
dataframe
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dataframe = dataframe.corr()
dataframe.to_csv('correlacion.csv')

# %%
dataframe = pd.read_csv("futbol.csv", parse_dates= True)
plt.figure(figsize=(100,80))
sns.heatmap(dataframe.corr(), cmap ='RdYlGn', linewidths = 0.30, annot = True)
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(dataframe)
# Out:
# array([[<AxesSubplot:xlabel='Unnamed: 0', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='ID', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='Age', ylabel='Unnamed: 0'>, ...,
#         <AxesSubplot:xlabel='GKKicking', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='GKPositioning', ylabel='Unnamed: 0'>,
#         <AxesSubplot:xlabel='GKReflexes', ylabel='Unnamed: 0'>],
#        [<AxesSubplot:xlabel='Unnamed: 0', ylabel='ID'>,
#         <AxesSubplot:xlabel='ID', ylabel='ID'>,
#         <AxesSubplot:xlabel='Age', ylabel='ID'>, ...,
#         <AxesSubplot:xlabel='GKKicking', ylabel='ID'>,
#         <AxesSubplot:xlabel='GKPositioning', ylabel='ID'>,
#         <AxesSubplot:xlabel='GKReflexes', ylabel='ID'>],
#        [<AxesSubplot:xlabel='Unnamed: 0', ylabel='Age'>,
#         <AxesSubplot:xlabel='ID', ylabel='Age'>,
#         <AxesSubplot:xlabel='Age', ylabel='Age'>, ...,
#         <AxesSubplot:xlabel='GKKicking', ylabel='Age'>,
# ...

# %%
sb.pairplot(dataframe.dropna(), hue='Value', height=4,kind='scatter')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9148\783684222.py in <cell line: 1>()
# ----> 1 sb.pairplot(dataframe.dropna(), hue='Value', height=4,kind='scatter')
#       2 plt.show()
#
# D:\Program Files\Python310\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Program Files\Python310\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# ...

# %%
test = dataframe.values

# %%
np.corrcoef(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9148\3599631708.py in <cell line: 1>()
# ----> 1 np.corrcoef(test)
#
# D:\Program Files\Python310\lib\site-packages\numpy\core\overrides.py in corrcoef(*args, **kwargs)
#
# D:\Program Files\Python310\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2819         warnings.warn('bias and ddof have no effect and are deprecated',
#    2820                       DeprecationWarning, stacklevel=3)
# -> 2821     c = cov(x, y, rowvar, dtype=dtype)
#    2822     try:
#    2823         d = diag(c)
#
# D:\Program Files\Python310\lib\site-packages\numpy\core\overrides.py in cov(*args, **kwargs)
#
# D:\Program Files\Python310\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2654             w *= aweights
# ...

# %%
correlacion_matrix_salary = np.corrcoef(salario, experiencia)
correlacion_matrix_salary

# %%
sns.heatmap(data=correlacion_matrix_salary, annot=True)
plt.show()
